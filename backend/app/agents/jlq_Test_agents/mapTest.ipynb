# %%
import requests
url = 'https://restapi.amap.com/v3/geocode/geo?address=北京市朝阳区阜通东大街6号&key=f5345c390cff8a23d5c42a395b765779'
response = requests.get(url)
json_response = response.json()
print(f"response:{response}")
print(f"jsonR:{json_response}")
# Out:
# response:<Response [200]>
# jsonR:{'status': '1', 'info': 'OK', 'infocode': '10000', 'count': '1', 'geocodes': [{'formatted_address': '广东省广州市天河区私立华联大学(北门)', 'country': '中国', 'province': '广东省', 'citycode': '020', 'city': '广州市', 'district': '天河区', 'township': [], 'neighborhood': {'name': [], 'type': []}, 'building': {'name': [], 'type': []}, 'adcode': '440106', 'street': [], 'number': [], 'location': '113.405314,23.160053', 'level': '兴趣点'}]}

# %%
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36',
}
url = 'https://restapi.amap.com/v3/geocode/geo?address=广东省广州市天河区私立华联大学&key=f5345c390cff8a23d5c42a395b765779'
response = requests.get(url, headers=headers)
json_response = response.json()
print("response:{response}")
print(f"jsonR:{json_response}")
# Out:
# response:{response}
# jsonR:{'status': '1', 'info': 'OK', 'infocode': '10000', 'count': '1', 'geocodes': [{'formatted_address': '广东省广州市天河区私立华联大学(北门)', 'country': '中国', 'province': '广东省', 'citycode': '020', 'city': '广州市', 'district': '天河区', 'township': [], 'neighborhood': {'name': [], 'type': []}, 'building': {'name': [], 'type': []}, 'adcode': '440106', 'street': [], 'number': [], 'location': '113.405314,23.160053', 'level': '兴趣点'}]}

# %%
import requests

url='https://restapi.amap.com/v3/staticmap?location=116.481485,39.990464&zoom=10&size=750*300&markers=mid,,A:116.481485,39.990464&key=f5345c390cff8a23d5c42a395b765779'
response = requests.get(url)
print(f"response:{response}")
print(f"jsonR:{json_response}")
# Out:
# response:<Response [200]>
